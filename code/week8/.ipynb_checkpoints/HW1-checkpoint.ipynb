# %% [markdown]
# ### Name 특징에서 유용한 정보 남기고 kdeplot 사용하기
# * 미션1) Level Up에서 ‘빈칸(NaN)을 더 현명하게 처리하기’를 진행합니다.
# * 미션2) 앞서 배운 kdeplot을 통해 Name 특징을 사용한 후 그래프가 어떻게 변화되는지 살펴봅니다.

# %%
import pandas as pd

df = pd.read_csv("../../COALA_DS_DATA/COALA_DS_DATA/week3/data/train.csv")

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
facet = sns.FacetGrid(df, hue = "Survived", aspect = 4)
facet.map(sns.kdeplot, 'Age')
facet.add_legend()

plt.show()

# %%
df[['Name', 'Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
df.loc[df['Name'].str.contains("Mr\."), 'Name'] = 'Mr'
df.loc[df['Name'].str.contains("Mrs\."), 'Name'] = 'Mrs'
df.loc[df['Name'].str.contains("Miss\."), 'Name'] = 'Miss'
df[['Name', 'Age']]
# Out:
#                       Name   Age
# 0                       Mr  22.0
# 1                      Mrs  38.0
# 2                     Miss  26.0
# 3                      Mrs  35.0
# 4                       Mr  35.0
# ..                     ...   ...
# 886  Montvila, Rev. Juozas  27.0
# 887                   Miss  19.0
# 888                   Miss   NaN
# 889                     Mr  26.0
# 890                     Mr  32.0
#
# [891 rows x 2 columns]

# %%
df['Name'] = df['Name'].map({
    'Mr': 0,
    'Mrs': 1,
    'Miss': 2
})

df['Name'] = df['Name'].fillna(3)
df
# Out:
#      PassengerId  Survived  Pclass  Name     Sex   Age  SibSp  Parch  \
# 0              1         0       3   3.0    male  22.0      1      0
# 1              2         1       1   3.0  female  38.0      1      0
# 2              3         1       3   3.0  female  26.0      0      0
# 3              4         1       1   3.0  female  35.0      1      0
# 4              5         0       3   3.0    male  35.0      0      0
# ..           ...       ...     ...   ...     ...   ...    ...    ...
# 886          887         0       2   3.0    male  27.0      0      0
# 887          888         1       1   3.0  female  19.0      0      0
# 888          889         0       3   3.0  female   NaN      1      2
# 889          890         1       1   3.0    male  26.0      0      0
# 890          891         0       3   3.0    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# 3              113803  53.1000  C123        S
# 4              373450   8.0500   NaN        S
# ..                ...      ...   ...      ...
# 886            211536  13.0000   NaN        S
# 887            112053  30.0000   B42        S
# 888        W./C. 6607  23.4500   NaN        S
# 889            111369  30.0000  C148        C
# 890            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df['Age'] = df['Age'].fillna(df.groupby('Name')['Age'].transform('mean'))
df
# Out:
#      PassengerId  Survived  Pclass  Name     Sex        Age  SibSp  Parch  \
# 0              1         0       3   3.0    male  22.000000      1      0
# 1              2         1       1   3.0  female  38.000000      1      0
# 2              3         1       3   3.0  female  26.000000      0      0
# 3              4         1       1   3.0  female  35.000000      1      0
# 4              5         0       3   3.0    male  35.000000      0      0
# ..           ...       ...     ...   ...     ...        ...    ...    ...
# 886          887         0       2   3.0    male  27.000000      0      0
# 887          888         1       1   3.0  female  19.000000      0      0
# 888          889         0       3   3.0  female  29.699118      1      2
# 889          890         1       1   3.0    male  26.000000      0      0
# 890          891         0       3   3.0    male  32.000000      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# 3              113803  53.1000  C123        S
# 4              373450   8.0500   NaN        S
# ..                ...      ...   ...      ...
# 886            211536  13.0000   NaN        S
# 887            112053  30.0000   B42        S
# 888        W./C. 6607  23.4500   NaN        S
# 889            111369  30.0000  C148        C
# 890            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
facet = sns.FacetGrid(df, hue = "Survived", aspect = 4)
facet.map(sns.kdeplot, 'Age')
facet.add_legend()

plt.show()
